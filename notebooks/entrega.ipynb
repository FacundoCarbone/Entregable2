# %% [markdown]
# # 10. Simulación de partidas y ranking en shooter online(Entrega)

# %%
import sys
import os
#Obtener la ruta absoluta del directorio raiz del proyecto
sys.path.append(os.path.abspath("../src"))

# %%
from resultados  import *
from puntajes import *
rondas = [
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
}
]
# ACA SE CREA EL RANKING QUE VA A ACUMULAR LOS PUNTOS A LO LARGO DE TODAS LAS RONDAS
estadisticas={
    'Shadow':{'kills':0,'asistencias':0,'muertes':0,'MVPs':0,'puntos':0},
         'Blaze':{'kills':0,'asistencias':0,'muertes':0,'MVPs':0,'puntos':0},
         'Viper':{'kills':0,'asistencias':0,'muertes':0,'MVPs':0,'puntos':0},
         'Frost':{'kills':0,'asistencias':0,'muertes':0,'MVPs':0,'puntos':0},
         'Reaper':{'kills':0,'asistencias':0,'muertes':0,'MVPs':0,'puntos':0}
         }

# Procesar cada ronda
for indice_ronda, datos_ronda in enumerate(rondas, start=1):
    puntajes_ronda = {}

    # Calcular puntos y actualizar estadísticas
    for jugador, datos in datos_ronda.items():
        kills = datos['kills']
        asistencias = datos['assists']
        muertes = int(datos['deaths'])
        puntos = calcular_puntos(kills, asistencias, muertes)
     #SE REALIZA LA ACUMULACION DE PUNTOS
        estadisticas[jugador]['kills'] += kills
        estadisticas[jugador]['asistencias'] += asistencias
        estadisticas[jugador]['muertes'] += muertes
        estadisticas[jugador]['puntos'] += puntos

        puntajes_ronda[jugador] = puntos

       # Determinar el MVP de la ronda
    mvp = determinar_mvp (puntajes_ronda)
    estadisticas[mvp]['MVPs'] += 1

      # Mostrar la tabla de resultados acumulados después de cada ronda
    print(f"Resultados después de la ronda {indice_ronda}:")
    mostrar_resultados(estadisticas)

# Mostrar el ranking final después de todas las rondas
print("Ranking final:")
mostrar_resultados(estadisticas)
# Out:
# Resultados después de la ronda 1:
# +-----------+---------+---------------+-----------+--------+----------+
# | Jugador   |   Kills |   Asistencias |   Muertes |   MVPs |   Puntos |
# +===========+=========+===============+===========+========+==========+
# | Shadow    |       2 |             1 |         1 |      1 |        6 |
# +-----------+---------+---------------+-----------+--------+----------+
# | Viper     |       1 |             2 |         1 |      0 |        4 |
# +-----------+---------+---------------+-----------+--------+----------+
# | Reaper    |       1 |             1 |         0 |      0 |        4 |
# +-----------+---------+---------------+-----------+--------+----------+
# | Blaze     |       1 |             0 |         0 |      0 |        3 |
# +-----------+---------+---------------+-----------+--------+----------+
# | Frost     |       0 |             1 |         0 |      0 |        1 |
# +-----------+---------+---------------+-----------+--------+----------+
#
# ...
